# %%
import coremltools as ct

# Load your Core ML model
mlmodel = ct.models.MLModel('Situps2.mlmodel')

# Print model description
print(mlmodel.get_spec())
# Out:
# specificationVersion: 4
# description {
#   input {
#     name: "x_1"
#     type {
#       multiArrayType {
#         shape: 1
#         shape: 19
#         shape: 200
#         dataType: FLOAT32
#       }
#     }
#   }
#   output {
#     name: "var_66"
#     type {
#       multiArrayType {
#         dataType: FLOAT32
#       }
#     }
#   }
#   metadata {
#     userDefined {
#       key: "com.github.apple.coremltools.version"
#       value: "8.0"
#     }
#     userDefined {
#       key: "com.github.apple.coremltools.source"
#       value: "torch==2.4.0"
#     }
#     userDefined {
#       key: "com.github.apple.coremltools.source_dialect"
#       value: "TorchScript"
#     }
#   }
# }
# neuralNetwork {
#   layers {
#     name: "expand_dims_0"
#     input: "x_1"
#     output: "expand_dims_0"
#     expandDims {
#       axes: -2
#     }
#   }
#   layers {
#     name: "conv_0"
#     input: "expand_dims_0"
#     output: "conv_0"
#     convolution {
#       outputChannels: 64
# ...
